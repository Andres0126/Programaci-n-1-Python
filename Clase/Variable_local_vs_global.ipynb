# %%
from math import sqrt
a = 10
s = 0
def sumas (b,c):
  b = 1
  print(b)
  # si modifico a dentro de la funcion, esta YA DEJA de ser una variable global
  #a = a + 1
  s = (a+b+c)
  print(s)
  #a = a + 1
  print(a)
  return 2*s

s = 4
s = sumas (s,s+1)
print(s)
print(a)
#print(b)
# Out:
# 1
# 16
# 10
# 32
# 10

# %% [markdown]
# Considere la siguiente figura que describe el entorno o ambito de las variables:
#
# ![image.png](data:image/png;base64,...)
#
# El codigo tiene las siguientes variables a,b,c, y s.

# %% [markdown]
# ¿ Donde es visible las variables ``b``, ``c``?
# ![image.png](data:image/png;base64,...)
#
# Las variables b y c solo son visibles dentro de la función ``sumas``, dado que solo estan definidas localmente en la función ``sumas``. Por ejemplo, ¿ qué pasa si elimino ``#`` en la linea de codigo 20 que esta en la parte de abajo?, es decir, ¿ qué pasa si la linea de codigo 20 es : ``print(b) ``?
#
#
# Similarmente, ¿donde es visible la variable ``a``?
#
# ![image.png](data:image/png;base64,...)
#
# La variable a es visible en cualquier parte del codigo. Observe la linea 10 del codigo.

# %% [markdown]
# Observe que la letra  ``s`` se usa para definir dos variables distintas: una variable global por fuera de la función ``sumas`` y otra variable local dentro de la función ``sumas``.
#
# **``S`` como variable global**
#
# ![image.png](data:image/png;base64,...)
#
# En la linea 3, se asigna el número 0 a la variable ``s``, es decir, la variable ``s`` apunta al valor 0.
#
# Luego, en la linea 13, el valor de 0 se reemplaza por 4. El Luego, en la linea 16, la función sumas es llamada, y el ultimo valor de ``s``, se pasa por valor a las variables locales ``b`` y ``c``. Por posición, la variable b copia o toma el valor 4 de s, y la variable c toma el valor de 5 = 4+1.
#
# **``S`` como variable local**
#
# ![image.png](data:image/png;base64,...)
#
#
# Dentro de la función``sumas``, la variable ``s`` global **NO** se puede acceder. Por ejemplo, antes de la linea 10, ¿ es posible acceder al valor de la variable ``s``? Respuesta: **NO**. Si elimina # en la linea 9, y corre ``print("valor de s local",s)``, se obtiene un error, porque localmente dentro de la función, antes de la linea 10, **la variable**  ``s``  **no esta definida o no existe.**
#
# La variable ``s`` local solo esta definida una vez la linea 10 es ejecutada, y su valor solo es visible dentro de la función. Observe que el valor de la variable ``s`` que se imprime en la linea 11 es distinto del valor global:
#
# Valor global de s = 4
#
# Valor local de s = 16

# %%
from math import sqrt
a = 10 # se define la variable global "a"
s = 0 # se define la variable global "s"

def sumas (b,c):
  b = 1 # se reescribe la variable local b, es decir, el valor de b ya no es 4, sino que se reemplaza por el valor de 1
  print("valor de b",b)
  #¿ qué pasa si elimino #?
  #print("valor de s local",s)
  s = (a+b+c) # suma una variable global con dos variables locales
  print("valor de s local",s)
  return 2*s

s = 4 # se redefine la variable global "s"
print("valor de s global",s)
s = sumas (s,s+1)
print(s)
print(a)
#¿ qué pasa si elimino #?
#print(b)
# Out:
# valor de s global 4
# valor de b 1
# valor de s local 16
# 32
# 10
